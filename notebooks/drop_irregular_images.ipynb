# %%
import pandas as pd
import pydicom
from joblib import Parallel, delayed
from tqdm import tqdm

# %%
ROOT_DIR = "C:/Users/evbruh/Downloads/rsna-intracranial-hemorrhage-detection/"
ALL_DF_PATH = ROOT_DIR + 'all_df.p'

# %%
all_df = pd.read_pickle(ALL_DF_PATH)

# %%
dcm = pydicom.read_file(all_df.loc[100].filepath[0])
dcm
# Out:
# (0008, 0018) SOP Instance UID                    UI: ID_000a8ee70
# (0008, 0060) Modality                            CS: 'CT'
# (0010, 0020) Patient ID                          LO: 'ID_5b1c46b9'
# (0020, 000d) Study Instance UID                  UI: ID_678f76a191
# (0020, 000e) Series Instance UID                 UI: ID_f93e957cb8
# (0020, 0010) Study ID                            SH: ''
# (0020, 0032) Image Position (Patient)            DS: ['-125.000', '-130.949', '78.368']
# (0020, 0037) Image Orientation (Patient)         DS: ['1.000000', '0.000000', '0.000000', '0.000000', '0.898794', '-0.438371']
# (0028, 0002) Samples per Pixel                   US: 1
# (0028, 0004) Photometric Interpretation          CS: 'MONOCHROME2'
# (0028, 0010) Rows                                US: 512
# (0028, 0011) Columns                             US: 512
# (0028, 0030) Pixel Spacing                       DS: ['0.488281', '0.488281']
# (0028, 0100) Bits Allocated                      US: 16
# ...

# %%
dcm.Rows, dcm.Columns
# Out:
# (512, 512)

# %%
li = []
def add_exotic_arr(idx):
    dcm = pydicom.read_file(all_df.loc[idx].filepath[0])
    if not dcm.Rows == dcm.Columns == 512:
        li.append((idx, (dcm.Rows, dcm.Columns)))

# %%
Parallel(n_jobs=4, prefer="threads")(delayed(add_exotic_arr)(i) for i in tqdm(range(all_df.shape[0])))
# Out:
# 100%|██████████| 674258/674258 [2:48:38<00:00, 66.64it/s]
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...

# %%
li = [(3300, (464, 464)),
 (9380, (408, 374)),
 (10938, (408, 374)),
 (11639, (638, 490)),
 (15897, (408, 374)),
 (20122, (666, 512)),
 (21505, (408, 374)),
 (25731, (462, 462)),
 (29243, (430, 404)),
 (29565, (462, 462)),
 (32420, (462, 462)),
 (36617, (768, 768)),
 (37172, (638, 490)),
 (38537, (464, 464)),
 (41009, (408, 374)),
 (44721, (638, 490)),
 (44837, (408, 374)),
 (46911, (462, 462)),
 (48997, (464, 464)),
 (49150, (430, 404)),
 (49838, (430, 404)),
 (53345, (464, 464)),
 (56339, (436, 436)),
 (56445, (436, 436)),
 (57372, (462, 462)),
 (59687, (436, 436)),
 (60975, (430, 404)),
 (61981, (638, 490)),
 (64276, (768, 768)),
 (65194, (430, 404)),
 (66277, (408, 374)),
 (66562, (464, 464)),
 (68523, (638, 490)),
 (73130, (638, 490)),
 (73300, (638, 490)),
 (80147, (464, 464)),
 (87039, (430, 404)),
 (89159, (638, 490)),
 (89694, (768, 768)),
 (94358, (464, 464)),
 (99805, (462, 462)),
 (103931, (436, 436)),
 (107415, (462, 462)),
 (107615, (408, 374)),
 (108359, (768, 768)),
 (112749, (408, 374)),
 (113902, (666, 512)),
 (122259, (464, 464)),
 (126079, (408, 374)),
 (130315, (430, 404)),
 (431246, (436, 436)),
 (432911, (408, 374)),
 (433092, (436, 436)),
 (433465, (464, 464)),
 (442997, (638, 490)),
 (444570, (462, 462)),
 (447622, (408, 374)),
 (448286, (464, 464)),
 (451925, (464, 464)),
 (453276, (436, 436)),
 (454082, (436, 436)),
 (454379, (430, 404)),
 (454532, (638, 490)),
 (459320, (436, 436)),
 (460162, (638, 490)),
 (460233, (638, 490)),
 (460352, (430, 404)),
 (461610, (464, 464)),
 (461885, (464, 464)),
 (465295, (408, 374)),
 (467528, (638, 490)),
 (468682, (462, 462)),
 (468799, (436, 436)),
 (469305, (666, 512)),
 (476595, (430, 404)),
 (476875, (462, 462)),
 (484010, (666, 512)),
 (484039, (436, 436)),
 (484186, (464, 464)),
 (486582, (436, 436)),
 (489162, (462, 462)),
 (489596, (436, 436)),
 (491895, (666, 512)),
 (493656, (430, 404)),
 (497388, (436, 436)),
 (499198, (464, 464)),
 (501642, (436, 436)),
 (506820, (408, 374)),
 (507516, (638, 490)),
 (509098, (436, 436)),
 (510567, (638, 490)),
 (511449, (768, 768)),
 (512643, (436, 436)),
 (515038, (430, 404)),
 (517673, (666, 512)),
 (517687, (430, 404)),
 (519697, (768, 768)),
 (522258, (768, 768)),
 (522763, (768, 768)),
 (522822, (462, 462)),
 (523049, (436, 436)),
 (524030, (464, 464)),
 (524608, (464, 464)),
 (531035, (666, 512)),
 (533323, (464, 464)),
 (534108, (462, 462)),
 (534837, (462, 462)),
 (536726, (462, 462)),
 (537101, (666, 512)),
 (545030, (638, 490)),
 (545212, (408, 374)),
 (545484, (638, 490)),
 (546420, (638, 490)),
 (550265, (464, 464)),
 (552578, (436, 436)),
 (552724, (436, 436)),
 (552743, (436, 436)),
 (558029, (638, 490)),
 (558756, (408, 374)),
 (561230, (430, 404)),
 (564763, (666, 512)),
 (567050, (462, 462)),
 (567900, (430, 404)),
 (567983, (462, 462)),
 (573335, (464, 464)),
 (576494, (464, 464)),
 (577952, (666, 512)),
 (582596, (638, 490)),
 (583138, (430, 404)),
 (585271, (768, 768)),
 (587593, (638, 490)),
 (589397, (638, 490)),
 (589453, (462, 462)),
 (602674, (666, 512)),
 (616508, (408, 374)),
 (616794, (666, 512)),
 (632738, (638, 490)),
 (634328, (462, 462)),
 (635490, (768, 768)),
 (636171, (638, 490)),
 (637420, (464, 464)),
 (637875, (638, 490)),
 (638144, (768, 768)),
 (638177, (638, 490)),
 (644135, (430, 404)),
 (644713, (638, 490)),
 (649575, (464, 464)),
 (667319, (464, 464)),
 (668318, (666, 512)),
 (670178, (436, 436)),
 (671654, (666, 512)),
 (673214, (462, 462))]

# %%
len(li)
# Out:
# 269

# %%
all_df.shape
# Out:
# (674258, 8)

# %%
all_df = all_df.drop(all_df.index[[el[0] for el in li]])

# %%
all_df.shape
# Out:
# (673989, 8)

# %%
import numpy as np
all_df = all_df.reindex(np.random.permutation(all_df.index))
all_df.index = np.arange(all_df.shape[0]).astype('int64')

# %%
all_df.to_pickle(ALL_DF_PATH)
